# %%
import pyterrier as pt
import os
os.environ["JAVA_HOME"] = "/home/andrew/Java"
os.environ["JVM_PATH"] = '/home/andrew/Java/jre/lib/server/libjvm.so'
if not pt.started():
    pt.init()
import json
import pandas as pd
import numpy as np
import itertools
from ir_measures import *
from ir_measures import evaluator
import ir_datasets as irds
from collections import defaultdict

# %% [markdown]
# # Fusion

# %%
with open('/home/andrew/Documents/Data/paced/scores.json') as f:
    score_dict = json.load(f)

# %%
bm25 = pd.read_csv('/home/andrew/Documents/Data/paced/bm25.csv', index_col=False).rename(columns={'qid': 'query_id', 'docid': 'doc_id'})

# %%
all_comb = map(lambda x : [x], score_dict.keys())
all_comb.append(list(score_dict.keys()))

# %%
DEFAULT = 10000

# %%
#score_dict = {k : {_k : defaultdict(lambda : (DEFAULT, DEFAULT), _v) for _k, _v in v.items()} for k, v in score_dict.items()}

# %%
def get_fusion_scores(target_sets, qids, C=0):
    records = []
    if len(target_sets) == 1:
        target = target_sets[0]
        for qid in qids:
            for doc_id, (score, rank) in target[qid].items():
                records.append({
                    'query_id': str(qid),
                    'doc_id': str(doc_id),
                    'score': score,
                })
        return pd.DataFrame.from_records(records)
    for qid in qids:
        all_sets = [set(target[qid].keys()) for target in target_sets]
        candidates = all_sets[0].union(*all_sets[1:])
        for candidate in candidates:
            for target in target_sets:
                if candidate not in target[qid]:
                    target[qid][candidate] = (0, 10000)
            scores = [1 / (C + target[qid][candidate][1] + 1) for target in target_sets]
            score = np.mean(scores)
            records.append({
                'query_id': str(qid),
                'doc_id': str(candidate),
                'score': score,
            })   
    return pd.DataFrame.from_records(records, dtype)

# %%
from tqdm.notebook import tqdm
def get_res(targetx, qids, evaluate_func):
    all = []
    for comb in tqdm(targetx):
        name = '_'.join(comb)
        targets = [score_dict[c] for c in comb]
        print(comb)
        res = get_fusion_scores(targets, qids)
        metrics = evaluate_func.calc_aggregate(res)
        metrics['name'] = name
        all.append(metrics)
        
    return pd.DataFrame.from_records(all)

# %%
qrels = irds.load('msmarco-passage/trec-dl-2019/judged').qrels_iter()
qidx = pd.DataFrame(qrels).drop_duplicates('query_id').query_id.to_list()

# %%
for q in list(qrels):
    print(q)

# %%
evaluate = evaluator([nDCG(cutoff=10), R(cutoff=100), R(cutoff=1000), AP(rel=2), RR, RR(cutoff=10), P(rel=2, cutoff=10), P(rel=2, cutoff=100)], qrels)

# %%
single = all_comb[:8]

# %%
sing = []
for comb in tqdm(single):
    name = '_'.join(comb)
    targets = [score_dict[c] for c in comb]
    res = get_fusion_scores(targets, qidx)
    metrics = evaluate.calc_aggregate(res)
    print(metrics)
    metrics['name'] = name
    sing.append(metrics)
    
sing_res = pd.DataFrame.from_records(sing)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# {RR: 0.795028067361668, R@1000: 0.7361896623436666, P(rel=2)@100: 0.19837209302325579, nDCG@10: 0.4795398322478302, AP(rel=2): 0.2892885548598652, P(rel=2)@10: 0.3883720930232557, RR@10: 0.7943798449612403, R@100: 0.44216959593012517}
# {RR: 0.7999811597981155, R@1000: 0.7151644083941056, P(rel=2)@100: 0.19767441860465115, nDCG@10: 0.5025129769993442, AP(rel=2): 0.3122462915682076, P(rel=2)@10: 0.42558139534883715, RR@10: 0.7965116279069767, R@100: 0.4256396605563712}
# {RR: 0.7901227131092042, R@1000: 0.7542767732682121, P(rel=2)@100: 0.20860465116279067, nDCG@10: 0.5155947995973377, AP(rel=2): 0.3122628149078852, P(rel=2)@10: 0.44186046511627913, RR@10: 0.7894056847545219, R@100: 0.46365963585710324}
# {RR: 0.7881239079364931, R@1000: 0.7510698325512497, P(rel=2)@100: 0.20441860465116277, nDCG@10: 0.508619963656044, AP(rel=2): 0.3093109273058641, P(rel=2)@10: 0.4232558139534884, RR@10: 0.7874677002583979, R@100: 0.4541612675508345}
# {RR: 0.7594837713242525, R@1000: 0.761899003921345, P(rel=2)@100: 0.22209302325581398, nDCG@10: 0.5231487651188188, AP(rel=2): 0.34536153385431695, P(rel=2)@10: 0.4558139534883721, RR@10: 0.757419712070875, R@100: 0.46224522609441565}
# {RR: 0.7551524800104892, R@1000: 0.772479444399284, P(rel=2)@100: 0.22348837209302325, nDCG@10: 0.530888202827822, AP(rel=2): 0.34950650600373584, P(rel=2)@10: 0.4674418604651163, RR@10: 0.7498062015503876, R@100: 0.4634621332317455}
# {RR: 0.7981288425554662, R@1000: 0.7358438435767506, P(rel=2)@100: 0.1997674418604651, nDCG@10: 0.48023404415130044, AP(rel=2): 0.28990266138769194, P(rel=2)@10: 0.3883720930232557, RR@10: 0.7974806201550387, R@100: 0.4458890695318092}
# {RR: 0.7884810320189177, R@1000: 0.7135551970269648, P(rel=2)@100: 0.1981395348837209, nDCG@10: 0.4986904634914372, AP(rel=2): 0.31438355835807386, P(rel=2)@10: 0.4209302325581395, RR@10: 0.7848837209302325, R@100: 0.4290887091388637}

# %%
sing_res
# Out:
#          RR    R@1000  P(rel=2)@100   nDCG@10  AP(rel=2)  P(rel=2)@10  \
# 0  0.795028  0.736190      0.198372  0.479540   0.289289     0.388372
# 1  0.799981  0.715164      0.197674  0.502513   0.312246     0.425581
# 2  0.790123  0.754277      0.208605  0.515595   0.312263     0.441860
# 3  0.788124  0.751070      0.204419  0.508620   0.309311     0.423256
# 4  0.759484  0.761899      0.222093  0.523149   0.345362     0.455814
# 5  0.755152  0.772479      0.223488  0.530888   0.349507     0.467442
# 6  0.798129  0.735844      0.199767  0.480234   0.289903     0.388372
# 7  0.788481  0.713555      0.198140  0.498690   0.314384     0.420930
#
#       RR@10     R@100      name
# 0  0.794380  0.442170      bm25
# 1  0.796512  0.425640       dph
# 2  0.789406  0.463660  bm25_rm3
# 3  0.787468  0.454161  bm25_bo1
# 4  0.757420  0.462245   dph_rm3
# 5  0.749806  0.463462   dph_bo1
# 6  0.797481  0.445889  smd_bm25
# 7  0.784884  0.429089   smd_dph

# %%
bm25
# Out:
#        query_id   doc_id    docno  rank      score  \
# 0        156493  8182161  8182161     0  31.156444
# 1        156493  6139386  6139386     1  31.032333
# 2        156493  3288600  3288600     2  30.953843
# 3        156493  3288596  3288596     3  30.754021
# 4        156493  2259183  2259183     4  30.362477
# ...         ...      ...      ...   ...        ...
# 42000    146187  4239826  4239826   995  13.695066
# 42001    146187  4874233  4874233   996  13.695066
# 42002    146187  6065118  6065118   997  13.695066
# 42003    146187  7392175  7392175   998  13.695066
# 42004    146187   135239   135239   999  13.685207
#
#                                                    query
# 0                                       do goldfish grow
# 1                                       do goldfish grow
# 2                                       do goldfish grow
# 3                                       do goldfish grow
# 4                                       do goldfish grow
# ...                                                  ...
# 42000  difference between a mcdouble and a double che...
# 42001  difference between a mcdouble and a double che...
# 42002  difference between a mcdouble and a double che...
# 42003  difference between a mcdouble and a double che...
# 42004  difference between a mcdouble and a double che...
#
# [42005 rows x 6 columns]

# %%
bm25 = bm25[['query_id', 'doc_id', 'score']].astype({'query_id': str, 'doc_id': str})

# %%
# convert bm25 to dict of qids to dict of doci to scores
bm25 = bm25.groupby('query_id').apply(lambda x: x.set_index('doc_id')['score'].to_dict()).to_dict()

# %%
import ir_measures
for x in ir_measures.iter_calc([nDCG@10, P@5, P(rel=2)@5, Judged@10], qrels, bm25):
    print(x)
# Out:
# Metric(query_id='156493', measure=P@5, value=1.0)
# Metric(query_id='156493', measure=nDCG@10, value=0.9634117275431489)
# Metric(query_id='1110199', measure=P@5, value=0.6)
# Metric(query_id='1110199', measure=nDCG@10, value=0.3706750815692151)
# Metric(query_id='1063750', measure=P@5, value=0.2)
# Metric(query_id='1063750', measure=nDCG@10, value=0.14281093555271182)
# Metric(query_id='130510', measure=P@5, value=1.0)
# Metric(query_id='130510', measure=nDCG@10, value=0.6073129006331783)
# Metric(query_id='489204', measure=P@5, value=0.4)
# Metric(query_id='489204', measure=nDCG@10, value=0.3233688044978225)
# Metric(query_id='573724', measure=P@5, value=0.6)
# Metric(query_id='573724', measure=nDCG@10, value=0.34278733477024653)
# Metric(query_id='168216', measure=P@5, value=1.0)
# Metric(query_id='168216', measure=nDCG@10, value=1.0)
# Metric(query_id='1133167', measure=P@5, value=1.0)
# Metric(query_id='1133167', measure=nDCG@10, value=0.5707912167619575)
# Metric(query_id='527433', measure=P@5, value=0.4)
# Metric(query_id='527433', measure=nDCG@10, value=0.2930110358433084)
# Metric(query_id='1037798', measure=P@5, value=0.2)
# Metric(query_id='1037798', measure=nDCG@10, value=0.1528664175953766)
# Metric(query_id='915593', measure=P@5, value=0.6)
# Metric(query_id='915593', measure=nDCG@10, value=0.41702088700508044)
# Metric(query_id='264014', measure=P@5, value=0.6)
# Metric(query_id='264014', measure=nDCG@10, value=0.3349224613565895)
# Metric(query_id='1121402', measure=P@5, value=1.0)
# Metric(query_id='1121402', measure=nDCG@10, value=0.7085303067457527)
# Metric(query_id='962179', measure=P@5, value=0.0)
# Metric(query_id='962179', measure=nDCG@10, value=0.0)
# Metric(query_id='1117099', measure=P@5, value=1.0)
# Metric(query_id='1117099', measure=nDCG@10, value=0.7375015234968479)
# Metric(query_id='148538', measure=P@5, value=0.2)
# Metric(query_id='148538', measure=nDCG@10, value=0.16388285383628032)
# Metric(query_id='451602', measure=P@5, value=0.2)
# Metric(query_id='451602', measure=nDCG@10, value=0.1222732034989334)
# Metric(query_id='359349', measure=P@5, value=1.0)
# Metric(query_id='359349', measure=nDCG@10, value=0.8919568008270394)
# Metric(query_id='1115776', measure=P@5, value=0.6)
# Metric(query_id='1115776', measure=nDCG@10, value=0.3347683579558962)
# Metric(query_id='1112341', measure=P@5, value=0.6)
# Metric(query_id='1112341', measure=nDCG@10, value=0.5879242969887917)
# Metric(query_id='131843', measure=P@5, value=1.0)
# Metric(query_id='131843', measure=nDCG@10, value=0.933745776545611)
# Metric(query_id='104861', measure=P@5, value=0.8)
# Metric(query_id='104861', measure=nDCG@10, value=0.7763057112117954)
# Metric(query_id='833860', measure=P@5, value=0.8)
# Metric(query_id='833860', measure=nDCG@10, value=0.6300426811446145)
# Metric(query_id='207786', measure=P@5, value=0.8)
# Metric(query_id='207786', measure=nDCG@10, value=0.5002400189998829)
# Metric(query_id='1114819', measure=P@5, value=1.0)
# Metric(query_id='1114819', measure=nDCG@10, value=0.6479599207147294)
# Metric(query_id='183378', measure=P@5, value=0.8)
# Metric(query_id='183378', measure=nDCG@10, value=0.36626565414202356)
# Metric(query_id='1106007', measure=P@5, value=0.2)
# Metric(query_id='1106007', measure=nDCG@10, value=0.36877307508450213)
# Metric(query_id='1124210', measure=P@5, value=1.0)
# Metric(query_id='1124210', measure=nDCG@10, value=0.6866637079152178)
# Metric(query_id='490595', measure=P@5, value=0.4)
# Metric(query_id='490595', measure=nDCG@10, value=0.22371473235978212)
# Metric(query_id='1103812', measure=P@5, value=0.6)
# Metric(query_id='1103812', measure=nDCG@10, value=0.5076989205249355)
# Metric(query_id='87181', measure=P@5, value=0.8)
# Metric(query_id='87181', measure=nDCG@10, value=0.5790263314078133)
# Metric(query_id='443396', measure=P@5, value=0.0)
# Metric(query_id='443396', measure=nDCG@10, value=0.06943122193677725)
# Metric(query_id='1121709', measure=P@5, value=0.0)
# Metric(query_id='1121709', measure=nDCG@10, value=0.0)
# Metric(query_id='87452', measure=P@5, value=0.8)
# Metric(query_id='87452', measure=nDCG@10, value=0.49861367776582255)
# Metric(query_id='855410', measure=P@5, value=0.8)
# Metric(query_id='855410', measure=nDCG@10, value=0.8811991369160118)
# Metric(query_id='1114646', measure=P@5, value=0.6)
# Metric(query_id='1114646', measure=nDCG@10, value=0.36314789718497964)
# Metric(query_id='19335', measure=P@5, value=0.4)
# Metric(query_id='19335', measure=nDCG@10, value=0.441088631408062)
# Metric(query_id='47923', measure=P@5, value=1.0)
# Metric(query_id='47923', measure=nDCG@10, value=0.5358972476921672)
# Metric(query_id='405717', measure=P@5, value=0.4)
# Metric(query_id='405717', measure=nDCG@10, value=0.37591540360593684)
# Metric(query_id='182539', measure=P@5, value=1.0)
# Metric(query_id='182539', measure=nDCG@10, value=0.645526870034055)
# Metric(query_id='1113437', measure=P@5, value=0.4)
# Metric(query_id='1113437', measure=nDCG@10, value=0.22650356641806893)
# Metric(query_id='1129237', measure=P@5, value=0.8)
# Metric(query_id='1129237', measure=nDCG@10, value=0.547601313988316)
# Metric(query_id='146187', measure=P@5, value=1.0)
# Metric(query_id='146187', measure=nDCG@10, value=0.7490351431774142)
# Metric(query_id='156493', measure=P(rel=2)@5, value=1.0)
# Metric(query_id='1110199', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='1063750', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='130510', measure=P(rel=2)@5, value=0.4)
# Metric(query_id='489204', measure=P(rel=2)@5, value=0.4)
# Metric(query_id='573724', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='168216', measure=P(rel=2)@5, value=1.0)
# Metric(query_id='1133167', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='527433', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1037798', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='915593', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='264014', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1121402', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='962179', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='1117099', measure=P(rel=2)@5, value=0.8)
# Metric(query_id='148538', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='451602', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='359349', measure=P(rel=2)@5, value=1.0)
# Metric(query_id='1115776', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1112341', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='131843', measure=P(rel=2)@5, value=1.0)
# Metric(query_id='104861', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='833860', measure=P(rel=2)@5, value=0.8)
# Metric(query_id='207786', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1114819', measure=P(rel=2)@5, value=1.0)
# Metric(query_id='183378', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1106007', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1124210', measure=P(rel=2)@5, value=1.0)
# Metric(query_id='490595', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1103812', measure=P(rel=2)@5, value=0.4)
# Metric(query_id='87181', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='443396', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='1121709', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='87452', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='855410', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='1114646', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='19335', measure=P(rel=2)@5, value=0.4)
# Metric(query_id='47923', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='405717', measure=P(rel=2)@5, value=0.0)
# Metric(query_id='182539', measure=P(rel=2)@5, value=0.4)
# Metric(query_id='1113437', measure=P(rel=2)@5, value=0.2)
# Metric(query_id='1129237', measure=P(rel=2)@5, value=0.6)
# Metric(query_id='146187', measure=P(rel=2)@5, value=0.8)
# Metric(query_id='156493', measure=Judged@10, value=1.0)
# Metric(query_id='1110199', measure=Judged@10, value=1.0)
# Metric(query_id='1063750', measure=Judged@10, value=0.9)
# Metric(query_id='130510', measure=Judged@10, value=1.0)
# Metric(query_id='489204', measure=Judged@10, value=1.0)
# Metric(query_id='573724', measure=Judged@10, value=1.0)
# Metric(query_id='168216', measure=Judged@10, value=1.0)
# Metric(query_id='1133167', measure=Judged@10, value=1.0)
# Metric(query_id='527433', measure=Judged@10, value=1.0)
# Metric(query_id='1037798', measure=Judged@10, value=1.0)
# Metric(query_id='915593', measure=Judged@10, value=1.0)
# Metric(query_id='264014', measure=Judged@10, value=1.0)
# Metric(query_id='1121402', measure=Judged@10, value=1.0)
# Metric(query_id='962179', measure=Judged@10, value=0.9)
# Metric(query_id='1117099', measure=Judged@10, value=1.0)
# Metric(query_id='148538', measure=Judged@10, value=1.0)
# Metric(query_id='451602', measure=Judged@10, value=1.0)
# Metric(query_id='359349', measure=Judged@10, value=1.0)
# Metric(query_id='1115776', measure=Judged@10, value=1.0)
# Metric(query_id='1112341', measure=Judged@10, value=1.0)
# Metric(query_id='131843', measure=Judged@10, value=1.0)
# Metric(query_id='104861', measure=Judged@10, value=1.0)
# Metric(query_id='833860', measure=Judged@10, value=1.0)
# Metric(query_id='207786', measure=Judged@10, value=1.0)
# Metric(query_id='1114819', measure=Judged@10, value=1.0)
# Metric(query_id='183378', measure=Judged@10, value=1.0)
# Metric(query_id='1106007', measure=Judged@10, value=1.0)
# Metric(query_id='1124210', measure=Judged@10, value=1.0)
# Metric(query_id='490595', measure=Judged@10, value=0.7)
# Metric(query_id='1103812', measure=Judged@10, value=1.0)
# Metric(query_id='87181', measure=Judged@10, value=1.0)
# Metric(query_id='443396', measure=Judged@10, value=1.0)
# Metric(query_id='1121709', measure=Judged@10, value=0.1)
# Metric(query_id='87452', measure=Judged@10, value=1.0)
# Metric(query_id='855410', measure=Judged@10, value=1.0)
# Metric(query_id='1114646', measure=Judged@10, value=1.0)
# Metric(query_id='19335', measure=Judged@10, value=0.9)
# Metric(query_id='47923', measure=Judged@10, value=1.0)
# Metric(query_id='405717', measure=Judged@10, value=1.0)
# Metric(query_id='182539', measure=Judged@10, value=1.0)
# Metric(query_id='1113437', measure=Judged@10, value=1.0)
# Metric(query_id='1129237', measure=Judged@10, value=0.7)
# Metric(query_id='146187', measure=Judged@10, value=1.0)

# %%
all = []
for comb in tqdm(all_comb):
    name = '_'.join(comb)
    targets = [score_dict[c] for c in comb]
    print(comb)
    res = get_fusion_scores(targets, qidx)
    metrics = evaluate.calc_aggregate(res)
    metrics['name'] = name
    all.append(metrics)
    
all_res = pd.DataFrame.from_records(all)
# Out:
#   0%|          | 0/255 [00:00<?, ?it/s]
# ['bm25']
# ['dph']
# ['bm25_rm3']
# ['bm25_bo1']
# ['dph_rm3']
# ['dph_bo1']
# ['smd_bm25']
# ['smd_dph']
# ['bm25', 'dph']
# ['bm25', 'bm25_rm3']
# ['bm25', 'bm25_bo1']
# ['bm25', 'dph_rm3']
# ['bm25', 'dph_bo1']
# ['bm25', 'smd_bm25']
# ['bm25', 'smd_dph']
# ['dph', 'bm25_rm3']
# ['dph', 'bm25_bo1']
# ['dph', 'dph_rm3']
# ['dph', 'dph_bo1']
# ['dph', 'smd_bm25']
# ['dph', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1']
# ['bm25_rm3', 'dph_rm3']
# ['bm25_rm3', 'dph_bo1']
# ['bm25_rm3', 'smd_bm25']
# ['bm25_rm3', 'smd_dph']
# ['bm25_bo1', 'dph_rm3']
# ['bm25_bo1', 'dph_bo1']
# ['bm25_bo1', 'smd_bm25']
# ['bm25_bo1', 'smd_dph']
# ['dph_rm3', 'dph_bo1']
# ['dph_rm3', 'smd_bm25']
# ['dph_rm3', 'smd_dph']
# ['dph_bo1', 'smd_bm25']
# ['dph_bo1', 'smd_dph']
# ['smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3']
# ['bm25', 'dph', 'bm25_bo1']
# ['bm25', 'dph', 'dph_rm3']
# ['bm25', 'dph', 'dph_bo1']
# ['bm25', 'dph', 'smd_bm25']
# ['bm25', 'dph', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1']
# ['bm25', 'bm25_rm3', 'dph_rm3']
# ['bm25', 'bm25_rm3', 'dph_bo1']
# ['bm25', 'bm25_rm3', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_rm3']
# ['bm25', 'bm25_bo1', 'dph_bo1']
# ['bm25', 'bm25_bo1', 'smd_bm25']
# ['bm25', 'bm25_bo1', 'smd_dph']
# ['bm25', 'dph_rm3', 'dph_bo1']
# ['bm25', 'dph_rm3', 'smd_bm25']
# ['bm25', 'dph_rm3', 'smd_dph']
# ['bm25', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph_bo1', 'smd_dph']
# ['bm25', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1']
# ['dph', 'bm25_rm3', 'dph_rm3']
# ['dph', 'bm25_rm3', 'dph_bo1']
# ['dph', 'bm25_rm3', 'smd_bm25']
# ['dph', 'bm25_rm3', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_rm3']
# ['dph', 'bm25_bo1', 'dph_bo1']
# ['dph', 'bm25_bo1', 'smd_bm25']
# ['dph', 'bm25_bo1', 'smd_dph']
# ['dph', 'dph_rm3', 'dph_bo1']
# ['dph', 'dph_rm3', 'smd_bm25']
# ['dph', 'dph_rm3', 'smd_dph']
# ['dph', 'dph_bo1', 'smd_bm25']
# ['dph', 'dph_bo1', 'smd_dph']
# ['dph', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3']
# ['bm25_rm3', 'bm25_bo1', 'dph_bo1']
# ['bm25_rm3', 'bm25_bo1', 'smd_bm25']
# ['bm25_rm3', 'bm25_bo1', 'smd_dph']
# ['bm25_rm3', 'dph_rm3', 'dph_bo1']
# ['bm25_rm3', 'dph_rm3', 'smd_bm25']
# ['bm25_rm3', 'dph_rm3', 'smd_dph']
# ['bm25_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25_rm3', 'dph_bo1', 'smd_dph']
# ['bm25_rm3', 'smd_bm25', 'smd_dph']
# ['bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['bm25_bo1', 'dph_rm3', 'smd_dph']
# ['bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['bm25_bo1', 'dph_bo1', 'smd_dph']
# ['bm25_bo1', 'smd_bm25', 'smd_dph']
# ['dph_rm3', 'dph_bo1', 'smd_bm25']
# ['dph_rm3', 'dph_bo1', 'smd_dph']
# ['dph_rm3', 'smd_bm25', 'smd_dph']
# ['dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3']
# ['bm25', 'dph', 'bm25_rm3', 'dph_bo1']
# ['bm25', 'dph', 'bm25_rm3', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3']
# ['bm25', 'dph', 'bm25_bo1', 'dph_bo1']
# ['bm25', 'dph', 'bm25_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_bo1', 'smd_dph']
# ['bm25', 'dph', 'dph_rm3', 'dph_bo1']
# ['bm25', 'dph', 'dph_rm3', 'smd_bm25']
# ['bm25', 'dph', 'dph_rm3', 'smd_dph']
# ['bm25', 'dph', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_bo1']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'smd_dph']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'dph_bo1']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'smd_dph']
# ['bm25', 'bm25_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'bm25_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['bm25', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['bm25', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'smd_bm25']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'smd_dph']
# ['dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1']
# ['dph', 'bm25_rm3', 'dph_rm3', 'smd_bm25']
# ['dph', 'bm25_rm3', 'dph_rm3', 'smd_dph']
# ['dph', 'bm25_rm3', 'dph_bo1', 'smd_bm25']
# ['dph', 'bm25_rm3', 'dph_bo1', 'smd_dph']
# ['dph', 'bm25_rm3', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['dph', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['dph', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['dph', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['dph', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['dph', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['dph', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['dph', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25_rm3', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['dph', 'bm25_rm3', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']
# ['bm25', 'dph', 'bm25_rm3', 'bm25_bo1', 'dph_rm3', 'dph_bo1', 'smd_bm25', 'smd_dph']

# %%
all_res.to_csv('/home/andrew/Documents/Data/paced/all_res.tsv', sep='\t', index=False)

# %%
all_res.head(20)
# Out:
#           RR    R@1000  P(rel=2)@100   nDCG@10  AP(rel=2)  P(rel=2)@10  \
# 0   0.795028  0.736190      0.198372  0.479540   0.289289     0.388372
# 1   0.799981  0.715164      0.197674  0.502513   0.312246     0.425581
# 2   0.790123  0.754277      0.208605  0.515595   0.312263     0.441860
# 3   0.788124  0.751070      0.204419  0.508620   0.309311     0.423256
# 4   0.759484  0.761899      0.222093  0.523149   0.345362     0.455814
# 5   0.755152  0.772479      0.223488  0.530888   0.349507     0.467442
# 6   0.798129  0.735844      0.199767  0.480234   0.289903     0.388372
# 7   0.788481  0.713555      0.198140  0.498690   0.314384     0.420930
# 8   0.819929  0.734850      0.204651  0.500367   0.304606     0.425581
# 9   0.782330  0.756277      0.205814  0.494619   0.299851     0.423256
# 10  0.790363  0.749617      0.203488  0.497416   0.303446     0.409302
# 11  0.814923  0.772555      0.214884  0.504498   0.327672     0.427907
# 12  0.801430  0.773534      0.215349  0.511440   0.326393     0.437209
# 13  0.796162  0.736360      0.199070  0.479837   0.289777     0.390698
# 14  0.808301  0.733597      0.206279  0.498375   0.304656     0.425581
# 15  0.808979  0.751300      0.209302  0.521877   0.320325     0.458140
# 16  0.802218  0.746235      0.209302  0.517801   0.321935     0.441860
# 17  0.776291  0.760337      0.210930  0.513920   0.330608     0.446512
# 18  0.789135  0.766270      0.211628  0.528692   0.333858     0.460465
# 19  0.831556  0.734532      0.205349  0.502127   0.306583     0.420930
#
#        RR@10     R@100           name
# 0   0.794380  0.442170           bm25
# 1   0.796512  0.425640            dph
# 2   0.789406  0.463660       bm25_rm3
# 3   0.787468  0.454161       bm25_bo1
# 4   0.757420  0.462245        dph_rm3
# 5   0.749806  0.463462        dph_bo1
# 6   0.797481  0.445889       smd_bm25
# 7   0.784884  0.429089        smd_dph
# 8   0.819897  0.449876       bm25_dph
# 9   0.824289  0.459397  bm25_bm25_rm3
# 10  0.783592  0.451241  bm25_bm25_bo1
# 11  0.799612  0.467266   bm25_dph_rm3
# 12  0.786822  0.462093   bm25_dph_bo1
# 13  0.795543  0.443126  bm25_smd_bm25
# 14  0.808269  0.452796   bm25_smd_dph
# 15  0.806848  0.465703   dph_bm25_rm3
# 16  0.813824  0.454142   dph_bm25_bo1
# 17  0.769601  0.452596    dph_dph_rm3
# 18  0.762209  0.448501    dph_dph_bo1
# 19  0.819897  0.451192   dph_smd_bm25

# %% [markdown]
# # Standard Eval

# %%
import os

# %%
DIR = '/home/andrew/Documents/Data/paced/members/'

# %%
files = [f for f in os.listdir(DIR)]

# %%
qrels = pd.DataFrame(irds.load('msmarco-passage/trec-dl-2019/judged').qrels_iter())
#qidx = pd.DataFrame(qrels).drop_duplicates('query_id').query_id.to_list()

# %%
evaluate = evaluator([nDCG(cutoff=10), R(cutoff=100), R(cutoff=1000), AP(rel=2), RR, RR(cutoff=10), P(rel=2, cutoff=10), P(rel=2, cutoff=100)], qrels)

# %%
all_res = {}
for f in files:
    tmp = []
    res = pd.read_csv(os.path.join(DIR, f), index_col=False)
    for row in res.itertuples():
        tmp.append(
            {
                'query_id': str(row.qid),
                'doc_id': str(row.docno),
                'score' : row.score
            }
        )
    all_res[f] = pd.DataFrame.from_records(tmp)

# %%
all_metric = []
for f in files:
    res = all_res[f]
    print(f)
    print(res.head())
    metrics = evaluate.calc_aggregate(res)
    metrics['name'] = f
    all_metric.append(metrics)
    
all_metric = pd.DataFrame.from_records(all_metric)
# Out:
# bo1_dir_LM.csv
#   query_id   doc_id      score
# 0  1037798  3620983  33.590197
# 1  1037798  8760873  29.805606
# 2  1037798  8760864  28.535555
# 3  1037798  8760867  27.323485
# 4  1037798  3641634  26.766174
# smd_bm25.csv
#   query_id   doc_id      score
# 0  1037798  8760864  26.007429
# 1  1037798  8760867  25.904425
# 2  1037798  3641634  25.410048
# 3  1037798  3620983  24.271134
# 4  1037798  4788864  24.007855
# rm3_DPH.csv
#   query_id   doc_id      score
# 0  1037798  3641634  17.549590
# 1  1037798  8760864  16.607452
# 2  1037798  3620983  13.873839
# 3  1037798  8760867  13.870762
# 4  1037798  8760873  12.866632
# smd_dir_LM.csv
#   query_id   doc_id      score
# 0  1037798  3641634  16.182809
# 1  1037798  8760864  15.746913
# 2  1037798  3620983  15.611668
# 3  1037798  8760867  15.226994
# 4  1037798  8760873  14.638440
# DPH.csv
#   query_id   doc_id      score
# 0   156493  2411918  14.820482
# 1   156493  6139386  14.592342
# 2   156493  8182166  14.150628
# 3   156493  1277727  13.628203
# 4   156493   885944  13.615840
# kl_DPH.csv
#   query_id   doc_id      score
# 0  1037798  3641634  14.551140
# 1  1037798  8760864  14.208769
# 2  1037798  3620983  13.801033
# 3  1037798  8760867  13.775536
# 4  1037798  8760873  13.208809
# smd_DPH.csv
#   query_id   doc_id      score
# 0  1037798  3641634  16.087631
# 1  1037798  8760864  15.463093
# 2  1037798  3620983  14.974594
# 3  1037798  8760867  14.914920
# 4  1037798  8760873  13.482684
# rm3_dir_LM.csv
#   query_id   doc_id      score
# 0  1037798  3641634  43.268100
# 1  1037798  8760864  34.101325
# 2  1037798  3641640  32.373211
# 3  1037798  3387556  32.261995
# 4  1037798  7466652  31.814817
# rm3_bm25.csv
#   query_id   doc_id      score
# 0  1037798  8760864  34.230643
# 1  1037798  8760867  32.585125
# 2  1037798  3641634  30.985745
# 3  1037798  8760873  29.863905
# 4  1037798  8760870  28.794420
# bo1_DPH.csv
#   query_id   doc_id      score
# 0  1037798  3641634  14.716510
# 1  1037798  8760864  14.480000
# 2  1037798  3620983  14.069086
# 3  1037798  8760867  14.042631
# 4  1037798  8760873  13.475995
# kl_dir_LM.csv
#   query_id   doc_id      score
# 0  1037798  3620983  33.590197
# 1  1037798  8760873  29.805606
# 2  1037798  8760864  28.535555
# 3  1037798  8760867  27.323485
# 4  1037798  3641634  26.766174
# dir_LM.csv
#   query_id   doc_id      score
# 0   156493  2411918  16.193452
# 1   156493  6139386  16.127133
# 2   156493  8182166  15.543202
# 3   156493   885944  15.199641
# 4   156493  8029433  15.079220
# bo1_bm25.csv
#   query_id   doc_id      score
# 0  1037798  8760867  29.126372
# 1  1037798  8760864  29.025579
# 2  1037798  3620983  26.946083
# 3  1037798  8760873  26.929815
# 4  1037798  8760870  25.386848
# bm25.csv
#   query_id   doc_id      score
# 0   156493  6139386  24.445697
# 1   156493  2411918  24.255240
# 2   156493  8182161  24.109553
# 3   156493  8182166  24.094844
# 4   156493  3288600  24.057416
# kl_bm25.csv
#   query_id   doc_id      score
# 0  1037798  8760867  28.521930
# 1  1037798  8760864  28.443669
# 2  1037798  3620983  26.403880
# 3  1037798  8760873  26.256777
# 4  1037798  8760870  24.757069

# %%
all_metric
# Out:
#     P(rel=2)@100  AP(rel=2)    R@1000     R@100   nDCG@10        RR     RR@10  \
# 0       0.162558   0.257223  0.683960  0.366888  0.461009  0.699680  0.695349
# 1       0.203023   0.310669  0.735046  0.463474  0.522755  0.805261  0.805233
# 2       0.222093   0.344307  0.761899  0.462245  0.523149  0.759464  0.757420
# 3       0.205581   0.311458  0.740987  0.458714  0.509298  0.792534  0.792534
# 4       0.197674   0.308977  0.715164  0.425640  0.502513  0.799962  0.796512
# 5       0.222791   0.347410  0.769047  0.461981  0.529974  0.767350  0.761849
# 6       0.198140   0.311069  0.713555  0.429089  0.498690  0.788462  0.784884
# 7       0.163721   0.251510  0.666246  0.348112  0.443779  0.696516  0.692276
# 8       0.216977   0.339016  0.772420  0.481293  0.530915  0.782787  0.777907
# 9       0.223488   0.348516  0.772479  0.463462  0.530888  0.755133  0.749806
# 10      0.157442   0.251904  0.676340  0.364268  0.464287  0.701413  0.697674
# 11      0.204884   0.308898  0.741005  0.460161  0.503690  0.772379  0.772379
# 12      0.218605   0.333140  0.784649  0.479416  0.535290  0.786135  0.784911
# 13      0.203488   0.309641  0.735547  0.462254  0.520925  0.806036  0.806008
# 14      0.217442   0.334154  0.781635  0.473523  0.537879  0.799252  0.797702
#
#     P(rel=2)@10            name
# 0      0.397674  bo1_dir_LM.csv
# 1      0.444186    smd_bm25.csv
# 2      0.455814     rm3_DPH.csv
# 3      0.448837  smd_dir_LM.csv
# 4      0.425581         DPH.csv
# 5      0.465116      kl_DPH.csv
# 6      0.420930     smd_DPH.csv
# 7      0.388372  rm3_dir_LM.csv
# 8      0.448837    rm3_bm25.csv
# 9      0.467442     bo1_DPH.csv
# 10     0.402326   kl_dir_LM.csv
# 11     0.446512      dir_LM.csv
# 12     0.458140    bo1_bm25.csv
# 13     0.441860        bm25.csv
# 14     0.462791     kl_bm25.csv

# %%
all_metric.to_csv('/home/andrew/Documents/Data/paced/members.csv', index=False)
